# %%
import json_helper as js
# tested the module and it works fine

# %%
js.json_to_pandas.load_dataframe('./DataEngineering.Labs.NOAADailySummaries/daily_summaries_FIPS10003_jan_2018_0.json')
# Out:
#                     date datatype            station attributes  value
# 0    2018-01-01T00:00:00     PRCP  GHCND:US1DENC0001       ,,N,      0
# 1    2018-01-01T00:00:00     SNWD  GHCND:US1DENC0001      T,,N,      0
# 2    2018-01-01T00:00:00     PRCP  GHCND:US1DENC0002       ,,N,      0
# 3    2018-01-01T00:00:00     SNOW  GHCND:US1DENC0002       ,,N,      0
# 4    2018-01-01T00:00:00     SNWD  GHCND:US1DENC0002      T,,N,      0
# ..                   ...      ...                ...        ...    ...
# 995  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0013       ,,N,      0
# 996  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0013       ,,N,      0
# 997  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0028       ,,N,      0
# 998  2018-01-27T00:00:00     SNOW  GHCND:US1DENC0028       ,,N,      0
# 999  2018-01-27T00:00:00     PRCP  GHCND:US1DENC0031       ,,N,      0
#
# [1000 rows x 5 columns]
